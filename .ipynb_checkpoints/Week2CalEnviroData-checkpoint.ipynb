# %% [markdown]
# Importing data from Cal EviroScreen 4.0 and doing some simple data exploration

# %%
import pandas as pd
import geopandas as gpd

# %%
# read and add shapefile to notebook
calenviro = gpd.read_file('data/calenvsc21shp.zip')
encoded="iso-8859-1"

# %%
type(calenviro)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
calenviro.head()
# Out:
#           Tract    ZIP         County    ApproxLoc  TotPop19    CIscore  \
# 0  6.083002e+09  93454  Santa Barbara  Santa Maria      4495  36.019653
# 1  6.083002e+09  93455  Santa Barbara  Santa Maria     13173  37.030667
# 2  6.083002e+09  93454  Santa Barbara  Santa Maria      2398  31.213140
# 3  6.083002e+09  93455  Santa Barbara       Orcutt      4496   6.639331
# 4  6.083002e+09  93455  Santa Barbara       Orcutt      4008  14.022852
#
#     CIscoreP     Ozone     OzoneP     PM2_5  ...  Elderly65  Hispanic  \
# 0  69.162885  0.034190  10.566273  7.567724  ...    12.5028   68.9210
# 1  70.637922  0.035217  11.561917  7.624775  ...     5.3519   78.6229
# 2  61.069087  0.034190  10.566273  7.548835  ...    12.8857   65.7214
# 3   5.988401  0.036244  13.615432  7.660570  ...    14.4128   22.9537
# 4  23.121533  0.036244  13.615432  7.663210  ...    18.8872   33.4082
#
#      White  AfricanAm  NativeAm  OtherMult    Shape_Leng    Shape_Area  \
# ...

# %%
calenviro.info
# Out:
# <bound method DataFrame.info of              Tract    ZIP         County     ApproxLoc  TotPop19    CIscore  \
# 0     6.083002e+09  93454  Santa Barbara   Santa Maria      4495  36.019653
# 1     6.083002e+09  93455  Santa Barbara   Santa Maria     13173  37.030667
# 2     6.083002e+09  93454  Santa Barbara   Santa Maria      2398  31.213140
# 3     6.083002e+09  93455  Santa Barbara        Orcutt      4496   6.639331
# 4     6.083002e+09  93455  Santa Barbara        Orcutt      4008  14.022852
# ...            ...    ...            ...           ...       ...        ...
# 8030  6.037430e+09  91016    Los Angeles      Monrovia      5339  17.124832
# 8031  6.037431e+09  91007    Los Angeles       Arcadia      4365  13.841990
# 8032  6.037431e+09  91016    Los Angeles      Monrovia      6758  39.697849
# 8033  6.037534e+09  90201    Los Angeles          Bell      6986  62.931044
# 8034  6.037534e+09  90201    Los Angeles  Bell Gardens      2358  63.315048
#
# ...

# %%
# how many rows and Columns 
calenviro.shape
# Out:
# (8035, 67)

# %%
# what are the columns?
calenviro.columns.to_list()
# Out:
# ['Tract',
#  'ZIP',
#  'County',
#  'ApproxLoc',
#  'TotPop19',
#  'CIscore',
#  'CIscoreP',
#  'Ozone',
#  'OzoneP',
#  'PM2_5',
#  'PM2_5_P',
#  'DieselPM',
#  'DieselPM_P',
#  'Pesticide',
#  'PesticideP',
#  'Tox_Rel',
#  'Tox_Rel_P',
#  'Traffic',
#  'TrafficP',
#  'DrinkWat',
#  'DrinkWatP',
#  'Lead',
#  'Lead_P',
#  'Cleanup',
#  'CleanupP',
#  'GWThreat',
#  'GWThreatP',
#  'HazWaste',
#  'HazWasteP',
#  'ImpWatBod',
#  'ImpWatBodP',
#  'SolWaste',
#  'SolWasteP',
#  'PollBurd',
#  'PolBurdSc',
#  'PolBurdP',
#  'Asthma',
#  'AsthmaP',
#  'LowBirtWt',
#  'LowBirWP',
#  'Cardiovas',
#  'CardiovasP',
#  'Educatn',
#  'EducatP',
#  'Ling_Isol',
#  'Ling_IsolP',
#  'Poverty',
#  'PovertyP',
#  'Unempl',
#  'UnemplP',
#  'HousBurd',
#  'HousBurdP',
#  'PopChar',
#  'PopCharSc',
#  'PopCharP',
#  'Child_10',
#  'Pop_10_64',
#  'Elderly65',
#  'Hispanic',
#  'White',
#  'AfricanAm',
#  'NativeAm',
#  'OtherMult',
#  'Shape_Leng',
#  'Shape_Area',
#  'AAPI',
#  'geometry']

# %%
# single column
calenviro['PollBurd'].sample(5)
# Out:
# 7743    37.105229
# 6777    45.793366
# 4911    27.023580
# 2707    24.853144
# 1907    44.671739
# Name: PollBurd, dtype: float64

# %%
calenviro.PollBurd.sample(5)
# Out:
# 3594    50.963623
# 6886    76.271543
# 502     44.005454
# 6073    67.498676
# 7118    39.679010
# Name: PollBurd, dtype: float64

# %%
# trimming the data 
calenviro.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 67 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tract       8035 non-null   float64
#  1   ZIP         8035 non-null   int64
#  2   County      8035 non-null   object
#  3   ApproxLoc   8035 non-null   object
#  4   TotPop19    8035 non-null   int64
#  5   CIscore     8035 non-null   float64
#  6   CIscoreP    8035 non-null   float64
#  7   Ozone       8035 non-null   float64
#  8   OzoneP      8035 non-null   float64
#  9   PM2_5       8035 non-null   float64
#  10  PM2_5_P     8035 non-null   float64
#  11  DieselPM    8035 non-null   float64
#  12  DieselPM_P  8035 non-null   float64
#  13  Pesticide   8035 non-null   float64
#  14  PesticideP  8035 non-null   float64
#  15  Tox_Rel     8035 non-null   float64
#  16  Tox_Rel_P   8035 non-null   float64
#  17  Traffic     8035 non-null   float64
# ...

# %% [markdown]
# Trim the cal enviro screen data to focus on pollution burden

# %%
# show a dataframe with a subset of columns
calenviro[['Tract','ZIP','ApproxLoc','County','CIscore','CIscoreP','PollBurd','Shape_Leng','Shape_Area','geometry']]
# Out:
#              Tract    ZIP     ApproxLoc         County    CIscore   CIscoreP  \
# 0     6.083002e+09  93454   Santa Maria  Santa Barbara  36.019653  69.162885
# 1     6.083002e+09  93455   Santa Maria  Santa Barbara  37.030667  70.637922
# 2     6.083002e+09  93454   Santa Maria  Santa Barbara  31.213140  61.069087
# 3     6.083002e+09  93455        Orcutt  Santa Barbara   6.639331   5.988401
# 4     6.083002e+09  93455        Orcutt  Santa Barbara  14.022852  23.121533
# ...            ...    ...           ...            ...        ...        ...
# 8030  6.037430e+09  91016      Monrovia    Los Angeles  17.124832  30.610187
# 8031  6.037431e+09  91007       Arcadia    Los Angeles  13.841990  22.566818
# 8032  6.037431e+09  91016      Monrovia    Los Angeles  39.697849  74.508321
# 8033  6.037534e+09  90201          Bell    Los Angeles  62.931044  97.049924
# 8034  6.037534e+09  90201  Bell Gardens    Los Angeles  63.315048  97.226425
#
# ...

# %%
# list desired column names
desired_columns = ['Tract','ZIP','ApproxLoc','County','PollBurd','geometry']

# %%
calenviro[desired_columns].sample(5)
# Out:
#              Tract    ZIP                               ApproxLoc  \
# 666   6.059089e+09  92843                            Garden Grove
# 7941  6.037320e+09  91608  Unincorporated Los Angeles County area
# 6896  6.037601e+09  90301                               Inglewood
# 347   6.059099e+09  92648                        Huntington Beach
# 4176  6.065044e+09  92223                                Beaumont
#
#            County   PollBurd  \
# 666        Orange  47.905154
# 7941  Los Angeles  64.921320
# 6896  Los Angeles  43.388057
# 347        Orange  39.474452
# 4176    Riverside  37.843523
#
#                                                geometry
# 666   POLYGON ((191096.158 -470746.677, 191142.759 -...
# 7941  POLYGON ((151767.169 -428963.078, 152381.208 -...
# 6896  POLYGON ((152299.188 -450893.998, 151485.141 -...
# 347   POLYGON ((183972.745 -478997.243, 184903.838 -...
# 4176  POLYGON ((279220.262 -445992.188, 278959.515 -...

# %% [markdown]
# Make a copy of the of the the trimmed data

# %%
calenviro_trim = calenviro[desired_columns].copy()
calenviro_trim
# Out:
#              Tract    ZIP     ApproxLoc         County   PollBurd  \
# 0     6.083002e+09  93454   Santa Maria  Santa Barbara  40.727364
# 1     6.083002e+09  93455   Santa Maria  Santa Barbara  53.869036
# 2     6.083002e+09  93454   Santa Maria  Santa Barbara  40.375822
# 3     6.083002e+09  93455        Orcutt  Santa Barbara  22.963796
# 4     6.083002e+09  93455        Orcutt  Santa Barbara  23.379744
# ...            ...    ...           ...            ...        ...
# 8030  6.037430e+09  91016      Monrovia    Los Angeles  42.609851
# 8031  6.037431e+09  91007       Arcadia    Los Angeles  39.697521
# 8032  6.037431e+09  91016      Monrovia    Los Angeles  68.866479
# 8033  6.037534e+09  90201          Bell    Los Angeles  61.773026
# 8034  6.037534e+09  90201  Bell Gardens    Los Angeles  73.957417
#
#                                                geometry
# 0     POLYGON ((-39795.070 -341919.191, -38126.384 -...
# 1     POLYGON ((-39795.070 -341919.191, -39803.632 -...
# ...

# %% [markdown]
# Subset the data to Include only Kern County

# %%
calenviro_trim[calenviro_trim.County == 'Kern']
# Out:
#              Tract    ZIP                        ApproxLoc County   PollBurd  \
# 1402  6.029002e+09  93309                      Bakersfield   Kern  37.876407
# 1403  6.029006e+09  93307                      Bakersfield   Kern  61.069075
# 1404  6.029004e+09  93263                          Shafter   Kern  58.223925
# 1405  6.029002e+09  93301                      Bakersfield   Kern  54.710493
# 1406  6.029000e+09  93308                          Oildale   Kern  55.269081
# ...            ...    ...                              ...    ...        ...
# 1548  6.029004e+09  93206  Unincorporated Kern County area   Kern  65.368844
# 1549  6.029003e+09  93252  Unincorporated Kern County area   Kern  49.569279
# 1550  6.029003e+09  93311  Unincorporated Kern County area   Kern  55.877262
# 1551  6.029000e+09  93308                          Oildale   Kern  46.245533
# 1552  6.029000e+09  93308  Unincorporated Kern County area   Kern  62.570717
#
# ...

# %% [markdown]
# Plotting of the data

# %%
calenviro_trim.plot()
# Out:
# <AxesSubplot: >

# %%
calenviro_trim.geometry
# Out:
# 0       POLYGON ((-39795.070 -341919.191, -38126.384 -...
# 1       POLYGON ((-39795.070 -341919.191, -39803.632 -...
# 2       POLYGON ((-38115.747 -341130.248, -38126.384 -...
# 3       POLYGON ((-37341.662 -348530.437, -37252.307 -...
# 4       POLYGON ((-39465.107 -348499.262, -38244.305 -...
#                               ...
# 8030    POLYGON ((185152.883 -426843.064, 185240.372 -...
# 8031    POLYGON ((179874.001 -429709.190, 179885.911 -...
# 8032    POLYGON ((184530.475 -428031.241, 184535.255 -...
# 8033    POLYGON ((167498.880 -447404.351, 167453.159 -...
# 8034    POLYGON ((169695.249 -447290.043, 169560.378 -...
# Name: geometry, Length: 8035, dtype: geometry

# %%
calenviro_trim.plot(
            figsize=(20,12),   #size of the plot (a bit bigger than the default)
            column = 'LINE',   # column that defines the color of the dots
            legend = True,     # add a legend           
            legend_kwds={
               'loc': 'upper right',
               'bbox_to_anchor':(1,1)
            }                  # this puts the legend to the side
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'LINE'
#
# The above exception was the direct cause of the following exception:
#
# ...
